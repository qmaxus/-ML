# %%
# !pip3 install tensorflow==2.13.1
# !pip3 install -U numpy
# !pip3 install opencv-python
# !pip3 install keras-segmentation
# Out:
# Requirement already satisfied: tensorflow==2.13.1 in ./nc/lib/python3.8/site-packages (2.13.1)
# Requirement already satisfied: absl-py>=1.0.0 in ./nc/lib/python3.8/site-packages (from tensorflow==2.13.1) (2.1.0)
# Requirement already satisfied: astunparse>=1.6.0 in ./nc/lib/python3.8/site-packages (from tensorflow==2.13.1) (1.6.3)
# Requirement already satisfied: flatbuffers>=23.1.21 in ./nc/lib/python3.8/site-packages (from tensorflow==2.13.1) (23.5.26)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in ./nc/lib/python3.8/site-packages (from tensorflow==2.13.1) (0.3.3)
# Requirement already satisfied: google-pasta>=0.1.1 in ./nc/lib/python3.8/site-packages (from tensorflow==2.13.1) (0.2.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in ./nc/lib/python3.8/site-packages (from tensorflow==2.13.1) (1.60.1)
# Requirement already satisfied: h5py>=2.9.0 in ./nc/lib/python3.8/site-packages (from tensorflow==2.13.1) (2.10.0)
# Requirement already satisfied: keras<2.14,>=2.13.1 in ./nc/lib/python3.8/site-packages (from tensorflow==2.13.1) (2.13.1)
# Requirement already satisfied: libclang>=13.0.0 in ./nc/lib/python3.8/site-packages (from tensorflow==2.13.1) (16.0.6)
# Requirement already satisfied: numpy<=1.24.3,>=1.22 in ./nc/lib/python3.8/site-packages (from tensorflow==2.13.1) (1.24.3)
# Requirement already satisfied: opt-einsum>=2.3.2 in ./nc/lib/python3.8/site-packages (from tensorflow==2.13.1) (3.3.0)
# Requirement already satisfied: packaging in ./nc/lib/python3.8/site-packages (from tensorflow==2.13.1) (23.2)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in ./nc/lib/python3.8/site-packages (from tensorflow==2.13.1) (4.25.3)
# Requirement already satisfied: setuptools in ./nc/lib/python3.8/site-packages (from tensorflow==2.13.1) (69.0.3)
# Requirement already satisfied: six>=1.12.0 in ./nc/lib/python3.8/site-packages (from tensorflow==2.13.1) (1.16.0)
# Requirement already satisfied: tensorboard<2.14,>=2.13 in ./nc/lib/python3.8/site-packages (from tensorflow==2.13.1) (2.13.0)
# Requirement already satisfied: tensorflow-estimator<2.14,>=2.13.0 in ./nc/lib/python3.8/site-packages (from tensorflow==2.13.1) (2.13.0)
# Requirement already satisfied: termcolor>=1.1.0 in ./nc/lib/python3.8/site-packages (from tensorflow==2.13.1) (2.4.0)
# Requirement already satisfied: typing-extensions<4.6.0,>=3.6.6 in ./nc/lib/python3.8/site-packages (from tensorflow==2.13.1) (4.5.0)
# Requirement already satisfied: wrapt>=1.11.0 in ./nc/lib/python3.8/site-packages (from tensorflow==2.13.1) (1.16.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in ./nc/lib/python3.8/site-packages (from tensorflow==2.13.1) (0.34.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in ./nc/lib/python3.8/site-packages (from astunparse>=1.6.0->tensorflow==2.13.1) (0.42.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in ./nc/lib/python3.8/site-packages (from tensorboard<2.14,>=2.13->tensorflow==2.13.1) (2.28.0)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in ./nc/lib/python3.8/site-packages (from tensorboard<2.14,>=2.13->tensorflow==2.13.1) (1.0.0)
# Requirement already satisfied: markdown>=2.6.8 in ./nc/lib/python3.8/site-packages (from tensorboard<2.14,>=2.13->tensorflow==2.13.1) (3.5.2)
# Requirement already satisfied: requests<3,>=2.21.0 in ./nc/lib/python3.8/site-packages (from tensorboard<2.14,>=2.13->tensorflow==2.13.1) (2.31.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in ./nc/lib/python3.8/site-packages (from tensorboard<2.14,>=2.13->tensorflow==2.13.1) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in ./nc/lib/python3.8/site-packages (from tensorboard<2.14,>=2.13->tensorflow==2.13.1) (3.0.1)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in ./nc/lib/python3.8/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.14,>=2.13->tensorflow==2.13.1) (4.2.4)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in ./nc/lib/python3.8/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.14,>=2.13->tensorflow==2.13.1) (0.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in ./nc/lib/python3.8/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.14,>=2.13->tensorflow==2.13.1) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in ./nc/lib/python3.8/site-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard<2.14,>=2.13->tensorflow==2.13.1) (1.3.1)
# Requirement already satisfied: importlib-metadata>=4.4 in ./nc/lib/python3.8/site-packages (from markdown>=2.6.8->tensorboard<2.14,>=2.13->tensorflow==2.13.1) (7.0.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in ./nc/lib/python3.8/site-packages (from requests<3,>=2.21.0->tensorboard<2.14,>=2.13->tensorflow==2.13.1) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in ./nc/lib/python3.8/site-packages (from requests<3,>=2.21.0->tensorboard<2.14,>=2.13->tensorflow==2.13.1) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in ./nc/lib/python3.8/site-packages (from requests<3,>=2.21.0->tensorboard<2.14,>=2.13->tensorflow==2.13.1) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in ./nc/lib/python3.8/site-packages (from requests<3,>=2.21.0->tensorboard<2.14,>=2.13->tensorflow==2.13.1) (2024.2.2)
# Requirement already satisfied: MarkupSafe>=2.1.1 in ./nc/lib/python3.8/site-packages (from werkzeug>=1.0.1->tensorboard<2.14,>=2.13->tensorflow==2.13.1) (2.1.5)
# Requirement already satisfied: zipp>=0.5 in ./nc/lib/python3.8/site-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<2.14,>=2.13->tensorflow==2.13.1) (3.17.0)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in ./nc/lib/python3.8/site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.14,>=2.13->tensorflow==2.13.1) (0.5.1)
# Requirement already satisfied: oauthlib>=3.0.0 in ./nc/lib/python3.8/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard<2.14,>=2.13->tensorflow==2.13.1) (3.2.2)
# Requirement already satisfied: numpy in ./nc/lib/python3.8/site-packages (1.24.3)
# Collecting numpy
#   Using cached numpy-1.24.4-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (5.6 kB)
# Using cached numpy-1.24.4-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (17.3 MB)
# Installing collected packages: numpy
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.24.3
#     Uninstalling numpy-1.24.3:
#       Successfully uninstalled numpy-1.24.3
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorflow 2.13.1 requires numpy<=1.24.3,>=1.22, but you have numpy 1.24.4 which is incompatible.
# tensorflow-gpu 2.2.0 requires scipy==1.4.1; python_version >= "3", but you have scipy 1.9.1 which is incompatible.
# tensorflow-gpu 2.2.0 requires tensorboard<2.3.0,>=2.2.0, but you have tensorboard 2.13.0 which is incompatible.
# tensorflow-gpu 2.2.0 requires tensorflow-estimator<2.3.0,>=2.2.0, but you have tensorflow-estimator 2.13.0 which is incompatible.
# Successfully installed numpy-1.24.4
# Requirement already satisfied: opencv-python in ./nc/lib/python3.8/site-packages (4.9.0.80)
# Requirement already satisfied: numpy>=1.17.0 in ./nc/lib/python3.8/site-packages (from opencv-python) (1.24.4)
# Requirement already satisfied: keras-segmentation in ./nc/lib/python3.8/site-packages (0.3.0)
# Requirement already satisfied: Keras>=2.0.0 in ./nc/lib/python3.8/site-packages (from keras-segmentation) (2.13.1)
# Requirement already satisfied: imageio==2.5.0 in ./nc/lib/python3.8/site-packages (from keras-segmentation) (2.5.0)
# Requirement already satisfied: imgaug==0.2.9 in ./nc/lib/python3.8/site-packages (from keras-segmentation) (0.2.9)
# Requirement already satisfied: opencv-python in ./nc/lib/python3.8/site-packages (from keras-segmentation) (4.9.0.80)
# Requirement already satisfied: tqdm in ./nc/lib/python3.8/site-packages (from keras-segmentation) (4.66.2)
# Requirement already satisfied: numpy in ./nc/lib/python3.8/site-packages (from imageio==2.5.0->keras-segmentation) (1.24.4)
# Requirement already satisfied: pillow in ./nc/lib/python3.8/site-packages (from imageio==2.5.0->keras-segmentation) (10.2.0)
# Requirement already satisfied: scipy in ./nc/lib/python3.8/site-packages (from imgaug==0.2.9->keras-segmentation) (1.9.1)
# Requirement already satisfied: scikit-image>=0.11.0 in ./nc/lib/python3.8/site-packages (from imgaug==0.2.9->keras-segmentation) (0.20.0)
# Requirement already satisfied: six in ./nc/lib/python3.8/site-packages (from imgaug==0.2.9->keras-segmentation) (1.16.0)
# Requirement already satisfied: matplotlib in ./nc/lib/python3.8/site-packages (from imgaug==0.2.9->keras-segmentation) (3.7.5)
# Requirement already satisfied: Shapely in ./nc/lib/python3.8/site-packages (from imgaug==0.2.9->keras-segmentation) (2.0.3)
# Requirement already satisfied: networkx>=2.8 in ./nc/lib/python3.8/site-packages (from scikit-image>=0.11.0->imgaug==0.2.9->keras-segmentation) (3.1)
# Requirement already satisfied: tifffile>=2019.7.26 in ./nc/lib/python3.8/site-packages (from scikit-image>=0.11.0->imgaug==0.2.9->keras-segmentation) (2023.7.10)
# Requirement already satisfied: PyWavelets>=1.1.1 in ./nc/lib/python3.8/site-packages (from scikit-image>=0.11.0->imgaug==0.2.9->keras-segmentation) (1.4.1)
# Requirement already satisfied: packaging>=20.0 in ./nc/lib/python3.8/site-packages (from scikit-image>=0.11.0->imgaug==0.2.9->keras-segmentation) (23.2)
# Requirement already satisfied: lazy_loader>=0.1 in ./nc/lib/python3.8/site-packages (from scikit-image>=0.11.0->imgaug==0.2.9->keras-segmentation) (0.3)
# Requirement already satisfied: contourpy>=1.0.1 in ./nc/lib/python3.8/site-packages (from matplotlib->imgaug==0.2.9->keras-segmentation) (1.1.1)
# Requirement already satisfied: cycler>=0.10 in ./nc/lib/python3.8/site-packages (from matplotlib->imgaug==0.2.9->keras-segmentation) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in ./nc/lib/python3.8/site-packages (from matplotlib->imgaug==0.2.9->keras-segmentation) (4.49.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in ./nc/lib/python3.8/site-packages (from matplotlib->imgaug==0.2.9->keras-segmentation) (1.4.5)
# Requirement already satisfied: pyparsing>=2.3.1 in ./nc/lib/python3.8/site-packages (from matplotlib->imgaug==0.2.9->keras-segmentation) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in ./nc/lib/python3.8/site-packages (from matplotlib->imgaug==0.2.9->keras-segmentation) (2.8.2)
# Requirement already satisfied: importlib-resources>=3.2.0 in ./nc/lib/python3.8/site-packages (from matplotlib->imgaug==0.2.9->keras-segmentation) (6.1.1)
# Requirement already satisfied: zipp>=3.1.0 in ./nc/lib/python3.8/site-packages (from importlib-resources>=3.2.0->matplotlib->imgaug==0.2.9->keras-segmentation) (3.17.0)

# %%
import tensorflow as tf

# %%
# !pip3 install tensorflow-gpu==2.2.0
# Out:
# Collecting tensorflow-gpu==2.2.0
#   Downloading tensorflow_gpu-2.2.0-cp38-cp38-manylinux2010_x86_64.whl (516.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 516.3/516.3 MB 2.6 MB/s eta 0:00:00m eta 0:00:010:00:03
# Requirement already satisfied: absl-py>=0.7.0 in ./nc/lib/python3.8/site-packages (from tensorflow-gpu==2.2.0) (2.1.0)
# Requirement already satisfied: astunparse==1.6.3 in ./nc/lib/python3.8/site-packages (from tensorflow-gpu==2.2.0) (1.6.3)
# Collecting gast==0.3.3 (from tensorflow-gpu==2.2.0)
#   Using cached gast-0.3.3-py2.py3-none-any.whl (9.7 kB)
# Requirement already satisfied: google-pasta>=0.1.8 in ./nc/lib/python3.8/site-packages (from tensorflow-gpu==2.2.0) (0.2.0)
# Collecting h5py<2.11.0,>=2.10.0 (from tensorflow-gpu==2.2.0)
#   Using cached h5py-2.10.0-cp38-cp38-manylinux1_x86_64.whl (2.9 MB)
# Collecting keras-preprocessing>=1.1.0 (from tensorflow-gpu==2.2.0)
#   Using cached Keras_Preprocessing-1.1.2-py2.py3-none-any.whl (42 kB)
# Requirement already satisfied: numpy<2.0,>=1.16.0 in ./nc/lib/python3.8/site-packages (from tensorflow-gpu==2.2.0) (1.24.3)
# Requirement already satisfied: opt-einsum>=2.3.2 in ./nc/lib/python3.8/site-packages (from tensorflow-gpu==2.2.0) (3.3.0)
# Requirement already satisfied: protobuf>=3.8.0 in ./nc/lib/python3.8/site-packages (from tensorflow-gpu==2.2.0) (4.25.3)
# Collecting tensorboard<2.3.0,>=2.2.0 (from tensorflow-gpu==2.2.0)
#   Downloading tensorboard-2.2.2-py3-none-any.whl (3.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 8.2 MB/s eta 0:00:00m eta 0:00:010:00:01
# Collecting tensorflow-estimator<2.3.0,>=2.2.0 (from tensorflow-gpu==2.2.0)
#   Downloading tensorflow_estimator-2.2.0-py2.py3-none-any.whl (454 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 454.6/454.6 kB 7.1 MB/s eta 0:00:00 MB/s eta 0:00:01
# Requirement already satisfied: termcolor>=1.1.0 in ./nc/lib/python3.8/site-packages (from tensorflow-gpu==2.2.0) (2.4.0)
# Requirement already satisfied: wrapt>=1.11.1 in ./nc/lib/python3.8/site-packages (from tensorflow-gpu==2.2.0) (1.16.0)
# Requirement already satisfied: six>=1.12.0 in ./nc/lib/python3.8/site-packages (from tensorflow-gpu==2.2.0) (1.16.0)
# Requirement already satisfied: grpcio>=1.8.6 in ./nc/lib/python3.8/site-packages (from tensorflow-gpu==2.2.0) (1.60.1)
# Requirement already satisfied: wheel>=0.26 in ./nc/lib/python3.8/site-packages (from tensorflow-gpu==2.2.0) (0.42.0)
# Collecting scipy==1.4.1 (from tensorflow-gpu==2.2.0)
#   Using cached scipy-1.4.1-cp38-cp38-manylinux1_x86_64.whl (26.0 MB)
# Collecting google-auth<2,>=1.6.3 (from tensorboard<2.3.0,>=2.2.0->tensorflow-gpu==2.2.0)
#   Downloading google_auth-1.35.0-py2.py3-none-any.whl (152 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 152.9/152.9 kB 5.2 MB/s eta 0:00:00
# Collecting google-auth-oauthlib<0.5,>=0.4.1 (from tensorboard<2.3.0,>=2.2.0->tensorflow-gpu==2.2.0)
#   Downloading google_auth_oauthlib-0.4.6-py2.py3-none-any.whl (18 kB)
# Requirement already satisfied: markdown>=2.6.8 in ./nc/lib/python3.8/site-packages (from tensorboard<2.3.0,>=2.2.0->tensorflow-gpu==2.2.0) (3.5.2)
# Requirement already satisfied: requests<3,>=2.21.0 in ./nc/lib/python3.8/site-packages (from tensorboard<2.3.0,>=2.2.0->tensorflow-gpu==2.2.0) (2.31.0)
# Requirement already satisfied: setuptools>=41.0.0 in ./nc/lib/python3.8/site-packages (from tensorboard<2.3.0,>=2.2.0->tensorflow-gpu==2.2.0) (69.0.3)
# Collecting tensorboard-plugin-wit>=1.6.0 (from tensorboard<2.3.0,>=2.2.0->tensorflow-gpu==2.2.0)
#   Downloading tensorboard_plugin_wit-1.8.1-py3-none-any.whl (781 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 781.3/781.3 kB 8.8 MB/s eta 0:00:0031m10.9 MB/s eta 0:00:01
# Requirement already satisfied: werkzeug>=0.11.15 in ./nc/lib/python3.8/site-packages (from tensorboard<2.3.0,>=2.2.0->tensorflow-gpu==2.2.0) (3.0.1)
# Collecting cachetools<5.0,>=2.0.0 (from google-auth<2,>=1.6.3->tensorboard<2.3.0,>=2.2.0->tensorflow-gpu==2.2.0)
#   Downloading cachetools-4.2.4-py3-none-any.whl (10 kB)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in ./nc/lib/python3.8/site-packages (from google-auth<2,>=1.6.3->tensorboard<2.3.0,>=2.2.0->tensorflow-gpu==2.2.0) (0.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in ./nc/lib/python3.8/site-packages (from google-auth<2,>=1.6.3->tensorboard<2.3.0,>=2.2.0->tensorflow-gpu==2.2.0) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in ./nc/lib/python3.8/site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.3.0,>=2.2.0->tensorflow-gpu==2.2.0) (1.3.1)
# Requirement already satisfied: importlib-metadata>=4.4 in ./nc/lib/python3.8/site-packages (from markdown>=2.6.8->tensorboard<2.3.0,>=2.2.0->tensorflow-gpu==2.2.0) (7.0.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in ./nc/lib/python3.8/site-packages (from requests<3,>=2.21.0->tensorboard<2.3.0,>=2.2.0->tensorflow-gpu==2.2.0) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in ./nc/lib/python3.8/site-packages (from requests<3,>=2.21.0->tensorboard<2.3.0,>=2.2.0->tensorflow-gpu==2.2.0) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in ./nc/lib/python3.8/site-packages (from requests<3,>=2.21.0->tensorboard<2.3.0,>=2.2.0->tensorflow-gpu==2.2.0) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in ./nc/lib/python3.8/site-packages (from requests<3,>=2.21.0->tensorboard<2.3.0,>=2.2.0->tensorflow-gpu==2.2.0) (2024.2.2)
# Requirement already satisfied: MarkupSafe>=2.1.1 in ./nc/lib/python3.8/site-packages (from werkzeug>=0.11.15->tensorboard<2.3.0,>=2.2.0->tensorflow-gpu==2.2.0) (2.1.5)
# Requirement already satisfied: zipp>=0.5 in ./nc/lib/python3.8/site-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<2.3.0,>=2.2.0->tensorflow-gpu==2.2.0) (3.17.0)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in ./nc/lib/python3.8/site-packages (from pyasn1-modules>=0.2.1->google-auth<2,>=1.6.3->tensorboard<2.3.0,>=2.2.0->tensorflow-gpu==2.2.0) (0.5.1)
# Requirement already satisfied: oauthlib>=3.0.0 in ./nc/lib/python3.8/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.3.0,>=2.2.0->tensorflow-gpu==2.2.0) (3.2.2)
# Installing collected packages: tensorflow-estimator, tensorboard-plugin-wit, scipy, keras-preprocessing, h5py, gast, cachetools, google-auth, google-auth-oauthlib, tensorboard, tensorflow-gpu
#   Attempting uninstall: tensorflow-estimator
#     Found existing installation: tensorflow-estimator 2.13.0
#     Uninstalling tensorflow-estimator-2.13.0:
#       Successfully uninstalled tensorflow-estimator-2.13.0
#   Attempting uninstall: scipy
#     Found existing installation: scipy 1.9.1
#     Uninstalling scipy-1.9.1:
#       Successfully uninstalled scipy-1.9.1
#   Attempting uninstall: h5py
#     Found existing installation: h5py 3.10.0
#     Uninstalling h5py-3.10.0:
#       Successfully uninstalled h5py-3.10.0
#   Attempting uninstall: gast
#     Found existing installation: gast 0.4.0
#     Uninstalling gast-0.4.0:
#       Successfully uninstalled gast-0.4.0
#   Attempting uninstall: cachetools
#     Found existing installation: cachetools 5.3.2
#     Uninstalling cachetools-5.3.2:
#       Successfully uninstalled cachetools-5.3.2
#   Attempting uninstall: google-auth
#     Found existing installation: google-auth 2.28.0
#     Uninstalling google-auth-2.28.0:
#       Successfully uninstalled google-auth-2.28.0
#   Attempting uninstall: google-auth-oauthlib
#     Found existing installation: google-auth-oauthlib 1.0.0
#     Uninstalling google-auth-oauthlib-1.0.0:
#       Successfully uninstalled google-auth-oauthlib-1.0.0
#   Attempting uninstall: tensorboard
#     Found existing installation: tensorboard 2.13.0
#     Uninstalling tensorboard-2.13.0:
#       Successfully uninstalled tensorboard-2.13.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# scikit-image 0.20.0 requires scipy<1.9.2,>=1.8; python_version <= "3.9", but you have scipy 1.4.1 which is incompatible.
# tensorflow 2.13.1 requires tensorboard<2.14,>=2.13, but you have tensorboard 2.2.2 which is incompatible.
# tensorflow 2.13.1 requires tensorflow-estimator<2.14,>=2.13.0, but you have tensorflow-estimator 2.2.0 which is incompatible.
# Successfully installed cachetools-4.2.4 gast-0.3.3 google-auth-1.35.0 google-auth-oauthlib-0.4.6 h5py-2.10.0 keras-preprocessing-1.1.2 scipy-1.4.1 tensorboard-2.2.2 tensorboard-plugin-wit-1.8.1 tensorflow-estimator-2.2.0 tensorflow-gpu-2.2.0

# %%
import cv2
import os
import cv2
import numpy as np
import tensorflow as tf
from keras.layers import *
from keras_segmentation.models.model_utils import get_segmentation_model
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# RuntimeError: module compiled against API version 0xe but this version of numpy is 0xd
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# ImportError: numpy.core.multiarray failed to import
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method __contains__ of dict object at 0x7f865620de00> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# ImportError                               Traceback (most recent call last)
# <ipython-input-20-7171f3768872> in <module>
#       3 import cv2
#       4 import numpy as np
# ----> 5 import tensorflow as tf
#       6 from keras.layers import *
#       7 from keras_segmentation.models.model_utils import get_segmentation_model
#
# ~/.local/lib/python3.8/site-packages/tensorflow/__init__.py in <module>
#      35 import typing as _typing
#      36
# ---> 37 from tensorflow.python.tools import module_util as _module_util
#      38 from tensorflow.python.util.lazy_loader import LazyLoader as _LazyLoader
#      39
#
# ~/.local/lib/python3.8/site-packages/tensorflow/python/__init__.py in <module>
#      35
#      36 from tensorflow.python import pywrap_tensorflow as _pywrap_tensorflow
# ---> 37 from tensorflow.python.eager import context
#      38
#      39 # pylint: enable=wildcard-import
#
# ~/.local/lib/python3.8/site-packages/tensorflow/python/eager/context.py in <module>
#      32 from tensorflow.python import pywrap_tfe
#      33 from tensorflow.python import tf2
# ---> 34 from tensorflow.python.client import pywrap_tf_session
#      35 from tensorflow.python.eager import executor
#      36 from tensorflow.python.eager import monitoring
#
# ~/.local/lib/python3.8/site-packages/tensorflow/python/client/pywrap_tf_session.py in <module>
#      17 # pylint: disable=invalid-import-order,g-bad-import-order, wildcard-import, unused-import
#      18 from tensorflow.python import pywrap_tensorflow
# ---> 19 from tensorflow.python.client._pywrap_tf_session import *
#      20 from tensorflow.python.client._pywrap_tf_session import _TF_SetTarget
#      21 from tensorflow.python.client._pywrap_tf_session import _TF_SetConfig
#
# ImportError: initialization failed

# %%
# !wget --no-check-certificate  'https://docs.google.com/uc?export=download&id=1dsdW4KgEH_Rr9rU468hUbcKc1CnYeU9w' -O MLtest_dataset.tar.xz
# !tar -xvf MLtest_dataset.tar.xz 
# !wget --no-check-certificate \
 'https://docs.google.com/uc?export=download&id=1d1PU2ldTmqLX-7-e5uYV8qodYWoE3CvS' -O last.h5
# !wget --no-check-certificate \
 'https://docs.google.com/uc?export=download&id=1ttWSv-Sd5hdhVPcxpbWDY3ZbjS51_l1d' -O best.h5

# %%
if not os.path.exists("annotations_prepped_train"):
    os.makedirs("annotations_prepped_train")

if not os.path.exists("images_prepped_train"):
    os.makedirs("images_prepped_train")

color = {'Mixed': (1, 1, 1), 'Dense': (2, 2, 2), 'Diffuse': (3, 3, 3)}
annotation = {}

for v in glob.glob('MLtest_dataset/MLtest_json (*).json'):
    with open(v, 'r') as f:
        json_annotation = json.load(f)
        for key, cap in json_annotation.items():
            if key in annotation:
                annotation[key]['regions'] += cap['regions']
            else:
                annotation[key] = cap

for key, value in annotation.items():
    name_photo = f"MLtest_dataset/{value['filename']}"
    try:
        img = cv2.imread(name_photo)
        msk_img = np.zeros((768, 768, 3), dtype='uint8')
        for b in value['regions']:
            crd = b["shape_attributes"]
            if 'Type' in b["region_attributes"]:
                x_min = int((crd["x"] * msk_img.shape[1]) / img.shape[1])
                y_min = int((crd["y"] * msk_img.shape[0]) / img.shape[0])
                x_max = int(((crd["width"] + crd["x"]) * msk_img.shape[1]) / img.shape[1])
                y_max = int(((crd["height"] + crd["y"]) * msk_img.shape[0]) / img.shape[0])
                box = np.array([[[x_min, y_min], [x_max, y_min], [x_max, y_max], [x_min, y_max]]], dtype=np.int32)
                cv2.fillPoly(msk_img, box, color[b["region_attributes"]["Type"]])
        img = cv2.resize(img, (768, 768))
        cv2.imwrite('images_prepped_train/' + value['filename'].replace('jpg', 'png'), img)
        cv2.imwrite('annotations_prepped_train/' + value['filename'].replace('jpg', 'png'), msk_img)
    except Exception as e:
        print(f'err {e} {name_photo}')

# %%
# %mkdir content

# %%
os.environ['CUDA_VISIBLE_DEVICES'] = '-1'  # 0-GPU -1-CPU
#physical_devices = tf.config.experimental.list_physical_devices('GPU')
#assert len(physical_devices) > 0, "Not enough GPU hardware devices available"
#config = tf.config.experimental.set_memory_growth(physical_devices[0], True)
#session = tf.compat.v1.keras.backend.get_session()


def get_image_arr(path, width, height, imgNorm="sub_mean", odering='channels_first'):
    if type(path) is np.ndarray:
        img = path
    else:
        img = cv2.imread(path, 1)

    if imgNorm == "sub_and_divide":
        img = np.float32(cv2.resize(img, (width, height))) / 127.5 - 1
    elif imgNorm == "sub_mean":
        img = cv2.resize(img, (width, height))
        img = img.astype(np.float32)
        img[:, :, 0] -= 103.939
        img[:, :, 1] -= 116.779
        img[:, :, 2] -= 123.68
        img = img[:, :, ::-1]
    elif imgNorm == "divide":
        img = cv2.resize(img, (width, height))
        img = img.astype(np.float32)
        img = img / 255.0

    if odering == 'channels_first':
        img = np.rollaxis(img, 2, 0)
    return img


def predict_my(model=None, inp=None):
    assert len(inp.shape) == 3, "Image should be h,w,3 "
    output_width = model.output_width
    output_height = model.output_height
    input_width = model.input_width
    input_height = model.input_height
    n_classes = model.n_classes
    x = get_image_arr(inp, input_width, input_height, odering='channels_last')
    pr = model.predict(np.array([x]))[0]
    pr = pr.reshape((output_height, output_width, n_classes)).argmax(axis=2)   
    return np.array(pr, dtype=np.uint8)


def railway_unet(frame, n_classes, limit_box_width_height, show=True):
    img = predict_my(model=h, inp=frame)
    color = {1: (255, 100, 0), 2: (0, 100, 255), 3: (5, 255, 0)}
    account_classes = {1: 0, 2: 0, 3: 0}

    for c in range(1, n_classes, 1):
        only_cat_hsv = cv2.inRange(img, c, c)
        contours, hierarchy = cv2.findContours(only_cat_hsv, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
        for cnt in contours:
            box = cv2.boundingRect(cnt)
            if clinket_rail(box, limit_box_width_height):
                frame = cv2.rectangle(frame, (box[0], box[1]), (box[0] + box[2], box[1] + box[3]), color[c], 5)
                account_classes[c] += 1
    if show:
        cv2.imshow('h1', frame)
        print(account_classes)
        cv2.waitKey(0)
    return f'Mixed: {account_classes[1]}, Dense: {account_classes[1]}, Diffuse: {account_classes[1]}.'


def clinket_rail(box, limit):
    return box[2] > limit[0] and box[3] > limit[1]


def net(n_classes, height, width, train, epochs):  # create a neural network for the segmentation of number
    img_input = Input(shape=(height, width, 3))
    conv1 = Conv2D(32, (3, 3), activation='relu', padding='same')(img_input)
    conv1 = Dropout(0.2)(conv1)
    conv1 = Conv2D(32, (3, 3), activation='relu', padding='same')(conv1)
    pool1 = MaxPooling2D((2, 2))(conv1)
    conv2 = Conv2D(64, (3, 3), activation='relu', padding='same')(pool1)
    conv2 = Dropout(0.2)(conv2)
    conv2 = Conv2D(64, (3, 3), activation='relu', padding='same')(conv2)
    pool2 = MaxPooling2D((2, 2))(conv2)
    conv3 = Conv2D(128, (3, 3), activation='relu', padding='same')(pool2)
    conv3 = Dropout(0.2)(conv3)
    conv3 = Conv2D(128, (3, 3), activation='relu', padding='same')(conv3)
    pool3 = MaxPooling2D((2, 2))(conv3)
    conv4 = Conv2D(256, (3, 3), activation='relu', padding='same')(pool3)
    conv4 = Dropout(0.2)(conv4)
    conv4 = Conv2D(256, (3, 3), activation='relu', padding='same')(conv4)
    up0 = concatenate([UpSampling2D((2, 2))(conv4), conv3], axis=-1)
    conv41 = Conv2D(128, (3, 3), activation='relu', padding='same')(up0)
    conv41 = Dropout(0.2)(conv41)
    conv41 = Conv2D(128, (3, 3), activation='relu', padding='same')(conv41)
    up1 = concatenate([UpSampling2D((2, 2))(conv41), conv2], axis=-1)
    conv4 = Conv2D(64, (3, 3), activation='relu', padding='same')(up1)
    conv4 = Dropout(0.2)(conv4)
    conv4 = Conv2D(64, (3, 3), activation='relu', padding='same')(conv4)
    up2 = concatenate([UpSampling2D((2, 2))(conv4), conv1], axis=-1)
    conv5 = Conv2D(32, (3, 3), activation='relu', padding='same')(up2)
    conv5 = Dropout(0.2)(conv5)
    conv5 = Conv2D(32, (3, 3), activation='relu', padding='same')(conv5)
    out = Conv2D(n_classes, (1, 1), padding='same')(conv5)

    model = get_segmentation_model(img_input, out)  # this would build the segmentation model
    if train == True:
        model.train(
            train_images="images_prepped_train/",
            train_annotations="annotations_prepped_train/",
            checkpoints_path="content/", epochs=epochs)
        model.save('last.h5')

    return model


n_classes = 4
height = 768
width = 768

h = net(n_classes=n_classes, height=height, width=width, train=True, epochs=2)
h.load_weights('content/.1')

frame = cv2.imread('images_prepped_train/чашка 11.png')
frame = cv2.resize(frame, (width, height))
limit_box_width_height = [10, 10]
account_classes = railway_unet(frame, n_classes, limit_box_width_height)
